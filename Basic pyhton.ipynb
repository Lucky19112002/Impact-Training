# %%
#+ operatio
print(1+2)
#- operatio
print(1-2)
#* operatio
print(1*3)
# divide operatio
print(5/2)
# remove decimel number of division
print(5//2)
# reminder operator (Modulp)
print(5 % 2)
# power operator (squre,cube)
print(5**2)
# stady increment in a value
i =0
i += 1
i -= 2
i *= 1

# comment
'''
Multiline Comment
'''
# or operator
print(2>3 or 2>1)
# and operator
print(1>0 and 10>5)
# not operator
print( not 2>3)

# %% [markdown]
# Loops

# %%
age =int(input("Enter your age : "))

if age >= 18:
    print("Adult")
    print("You can vote")
elif age<18 and age>3 :
    print("School")
else:
    print("Child")
print("Thank You")

# %%
a = int(input("Enter first number : "))
oprt = input("Enter operator (+,-,/,*,%) : ")
b = int(input("Enter second number : "))
if  oprt == '+':
    print(a+b)
elif oprt == '-':
    print(a-b)
elif oprt == '*':
    print(a*b)
elif oprt == '/':
    print(a/b)
elif oprt == '%':
    print(a%b)
else:
    print("Invalid operator")

# %%
# while
i =1
'''
while i <=5:
    print(i)
    i+=1
'''
while i <=5:
    print(i * "*")
    i+=1

# %%
# for loop
for item in range(5):
    print(item)


marks  =[95,98,78]
marks.append(99)
marks.insert(0,99)
print(99 in marks)
print(marks[0:4])

for scoe in marks:
    print(scoe)

j = 0
while j < len(marks):
    print(marks[j])
    j+=1
# Out:
# 0
# 1
# 2
# 3
# 4
# True
# [99, 95, 98, 78]
# 99
# 95
# 98
# 78
# 99
# 99
# 95
# 98
# 78
# 99

# %%
# list -> []
# Tuple -> () , opctional brackets
# Set -> {}
# Dictionary -> {  "key" : value , "key2" : value2}
  

#    Functions

'''
import math
dir(math)

user def dunction

def function_name(perameters):
    //do things 
'''

# %%
paecel=[50,80,30,20,70]
#print(paecel)
n = len(paecel)
print(n)
max_weight = 80
for i in range(n):

# Traverse the list from 0 to n-i-1
# (The last element will already be in place after first pass, so no need to re-check)
    for j in range(0, n-i-1):
    # Swap if current element is greater than next
        if paecel[j] > paecel[j+1]:
            paecel[j], paecel[j+1] = paecel[j+1], paecel[j]
print(paecel)
# Out:
# 5
# [20, 30, 50, 70, 80]

# %% [markdown]
# Climbing Stair Problem :
#
# ![image.png](attachment:image.png)

# %%
def climbStairs(n: int) -> int:
    one , two = 1,1
    for i in range(n-1):
        temp = one
        one = one + two
        two = temp
    return one
lenth = int(input("Enter the length: "))
climbStairs(lenth)
# Out:
# 89
